# %% [markdown]
# ### **Functions in Python**
#
# A **function** in Python is a reusable block of organized code designed to perform a single, related action. Functions help reduce code repetition, make programs modular, and improve overall readability.

# %% [markdown]
# def function_name():
#     # code

# %%
def greet():
    # This is the function body
    print("Hello from a function!")

# Calling the function
greet()
# Out:
# Hello from a function!

# %%
def greet():
    print("Hello Sami")

greet()
# Out:
# Hello Sami

# %%
def welcome():
    print("Welcome to Data Science")

welcome()
# Out:
# Welcome to Data Science

# %%
def welcome():
    print("Welcome Sami")

welcome()
welcome()
welcome()
# Out:
# Welcome Sami
# Welcome Sami
# Welcome Sami

# %% [markdown]
# ### **2. Parameters vs. Arguments**
#
# Parameters are the placeholders defined in the function header.
#
# Arguments are the actual values passed to the function when it is called

# %%
def greet(name):  # parameters
    print(f"Hello {name}")

greet("Sami") # arguments
greet("Ali")
greet("Qasim")
# Out:
# Hello Sami
# Hello Ali
# Hello Qasim

# %%
def student_info(name, age, field):
    print(f"Name: {name}")
    print(f"Age: {age}")
    print(f"Field: {field}")

student_info("Sami", 21, "Data Science")
# Out:
# Name: Sami
# Age: 21
# Field: Data Science

# %% [markdown]
# ### **3. Returning Values**
# Functions can send data back to the caller using the return statement. Once a return statement is reached, the function exits immediately. If no return statement is specified, the function returns None by default

# %%
def add_numbers(a, b):
    return a + b  # Returns the sum to the caller

result = add_numbers(5, 7)
print(result)  # Output: 12
# Out:
# 12

# %% [markdown]
# Note
# print() → result screen par dikhata hai
#
# return → result function ke bahar bhejta hai

# %%
def calculate_average(marks):
    total = sum(marks)
    average = total / len(marks)
    return average

marks = [90, 83, 76, 53]
avg = calculate_average(marks)
print(avg)
# Out:
# 75.5

# %%
def calculate_total(numbers):
    total = 0

    for number in numbers:
        total += number

    return total

sales = [90, 83, 76, 53]
total_sales = calculate_total(sales)
print(total_sales)
# Out:
# 302

# %%
def performance_status(average):
    if average >= 80:
        return "Excellent"
    elif average >= 70:
        return "Good"
    elif average >= 60:
        return "Average"
    else:
        return "Needs Improvement"

status = performance_status(84)

print(status)
# Out:
# Excellent

# %% [markdown]
# ### **Keyword Arguments**

# %%
def student(name, age, city):
    print(name, age, city)

student(
    city="Layyah",
    name="Sami",
    age=21
)

student("Sami", 21, "Layyah")
# Out:
# Sami 21 Layyah
# Sami 21 Layyah

# %%
def analyze_marks(marks):
    total = sum(marks)
    average = total / len(marks)
    highest = max(marks)
    lowest = min(marks)

    return total, average, highest, lowest

total, average, highest, lowest = analyze_marks(marks)

print(total, average, highest, lowest)
# Out:
# 302 75.5 90 53

# %% [markdown]
# ### **🎯 TASK 1 — Basic Function**

# %%
def calculate_square(number):
    square = number * number
    return square

result = calculate_square(5)
print(f"Square of 5: {result}")
# Out:
# Square of 5: 25

# %% [markdown]
# ### **🎯 TASK 2 — Greeting Function**

# %%
def greet_student(name, field):
    print(f"Hello {name}, Welcome to {field}!")

greet_student("Sami", "Data Science")
# Out:
# Hello Sami, Welcome to Data Science!

# %% [markdown]
# ### **🎯 TASK 3 — Sales Function**

# %%
def calculate_total_sales(sale):
    total = 0

    for s in sale:
        total += s

    return total

sales = [1200, 4500, 7800, 3200]

result = calculate_total_sales(sales)

print(result)
# Out:
# 16700

# %% [markdown]
# ### **🎯 TASK 4 — Performance Function**

# %%
def get_performance_status(average):
    if average >= 90:
        return "Outstanding"
    elif average >= 80:
        return "Excellent"
    elif average >= 70:
        return "Good"
    elif average >= 60:
        return "Average"
    else:
        return "Needs Improvement"

status = get_performance_status(67)
print(status)
# Out:
# Average

# %%
90+ → Outstanding
80+ → Excellent
70+ → Good
60+ → Average
below 60 → Needs Improvement
