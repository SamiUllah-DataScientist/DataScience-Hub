# %% [markdown]
# ## **Dictionary in Python**
# A Python dictionary is a built-in data structure used to store data in key-value pairs. It is optimized for retrieving data quickly when you know the specific name (the key) rather than a numeric index.
#
# In Python 3.7 and later, dictionaries are ordered (they maintain the order of insertion), changeable (mutable), and do not allow duplicate keys.

# %% [markdown]
# ### **1. Creating a Dictionary**
# You can create a dictionary using curly brackets {} or the built-in dict() constructor.

# %%
# Using curly brackets
user = {
    "name": "Alice",
    "age": 28,
    "is_member": True
}

print(user)
# Using the dict() constructor
user_2 = dict(name="Bob", age=32, is_member=False)

print(user_2)
# Out:
# {'name': 'Alice', 'age': 28, 'is_member': True}
# {'name': 'Bob', 'age': 32, 'is_member': False}

# %%
student = {
    "name": "Sami Ullah",
    "age": 21,
    "field": "Data Science",
    "cgpa": 3.69
}

print(student)

print("=" * 40)
print("       STUDENT INFORMATION PORTAL")
print("="*40)
for var in student:
    print(f"{var.title():<10}    -> {student[var]:<20}")
# Out:
# {'name': 'Sami Ullah', 'age': 21, 'field': 'Data Science', 'cgpa': 3.69}
# ...
#        STUDENT INFORMATION PORTAL
# ...
# Name          -> Sami Ullah
# Age           -> 21
# Field         -> Data Science
# Cgpa          -> 3.69

# %%
marks = {
    1: 85,
    2: 92,
    3: 78
}

print(marks)
print(f"Keys: {list(marks.keys())}")
print(f"Values: {list(marks.values())}")
# Out:
# {1: 85, 2: 92, 3: 78}
# Keys: [1, 2, 3]
# Values: [85, 92, 78]

# %%
student = {
    "name": "Sami",
    "age": 21,
    "cgpa": 3.69,
    "skills": ["Python", "SQL"],
    "active": True
}

for var in student:
    print(type(student[var]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'bool'>

# %% [markdown]
# ### **2. Accessing Values**
# You can retrieve a value by placing its key inside square brackets [] or by using the .get() method.

# %%
# Standard way (Raises KeyError if the key doesn't exist)
print(user["name"])  # Output: Alice

# Safer way (Returns None or a default value if the key doesn't exist)
print(user.get("email"))        # Output: None
print(user.get("email", "N/A")) # Output: N/A
# Out:
# Alice
# None
# N/A

# %%
student = {
    "name": "Sami",
    "age": 21,
    "cgpa": 3.69
}

print(student["name"])
print(student["cgpa"])
print(student.get("city", "Not Available"))
# Out:
# Sami
# 3.69
# Not Available

# %% [markdown]
# ### **3. Adding and Modifying Items**
# You can add a new key-value pair or update an existing one using the assignment operator =.

# %%
# Adding a new key-value pair
user["email"] = "alice@example.com"

# Updating an existing value
user["age"] = 29

# %% [markdown]
# ### **4. Removing Items**
# Python provides multiple ways to delete items based on your needs:

# %%
# Removes a specific key and returns its value
age = user.pop("age") 

# Removes and returns the last inserted key-value pair as a tuple
last_item = user.popitem() 

# Deletes an item directly using the 'del' keyword
del user["is_member"]

# Empties the entire dictionary
user.clear()

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name Sami
# age 21
# cgpa 3.69

# %% [markdown]
# ### **Nested Dictionary**

# %%
student = {
    "name": "Sami",
    "academic": {
        "matric_percentage": 96.55,
        "inter_percentage": 84.5,
        "cgpa": 3.69
    }
}

print(student["academic"]["inter_percentage"])
# Out:
# 84.5

# %%
student = {
    "name": "Sami",
    "skills": ["Python", "SQL", "Excel"]
}

print(student["skills"])
print(student["skills"][:2])
# Out:
# ['Python', 'SQL', 'Excel']
# ['Python', 'SQL']

# %%
students = [
    {"name": "Ali", "marks": 85},
    {"name": "Sami", "marks": 95},
    {"name": "Ayesha", "marks": 90}
]

for i in students:
    print(i["name"])
# Out:
# Ali
# Sami
# Ayesha

# %% [markdown]
# ## **Important for Data Science Projects**

# %%
students = [
    {"student_id": 101, "name": "Ali", "age": 20, "marks": 85},
    {"student_id": 102, "name": "Sami", "age": 21, "marks": 95},
    {"student_id": 103, "name": "Ayesha", "age": 20, "marks": 90}
]

print("-" * 50)
print("Student_ID:     | Age   | Name             | Marks")
print("=" * 50)

for i in students:
    print(f"{i["student_id"]:<14} | {i["age"]:<5} | {i["name"]:<16} | {i["marks"]}")
# Out:
# --------------------------------------------------
# Student_ID     | Age   | Name             | Marks
# ...
# 101            | 20    | Ali              | 85
# 102            | 21    | Sami             | 95
# 103            | 20    | Ayesha           | 90

# %%
student = {

           "name":"Sami",
           "semester": 4,
           "age": 21,
           "university": "VU"
           }
print(student)

student["email"] = "sami@gmail.com"
student["age"] = 23
print(student)
# Out:
# {'name': 'Sami', 'semester': 4, 'age': 21, 'university': 'VU'}
# {'name': 'Sami', 'semester': 4, 'age': 23, 'university': 'VU', 'email': 'sami@gmail.com'}

# %%
students = {
    "Ali": 85,
    "Sami": 95,
    "Hamza": 72,
    "Ayesha": 90
}

high_marks = 0
highest_student = ""
total_marks = 0
count_students = 0

print("=" * 30)
print("       STUDENT RECORDS")
print("=" * 30)

print(f"Total Students: {len(students)}")

print("\nName       | Marks")
print("-" * 25)

for name, mark in students.items():

    print(f"{name:<10} | {mark}")

    total_marks += mark

    if mark > high_marks:
        high_marks = mark
        highest_student = name

    if mark >= 80:
        count_students += 1

average_marks = total_marks / len(students)

print("\n" + "=" * 30)
print(f"Highest Marks: {high_marks}")
print(f"Highest Student: {highest_student}")
print(f"Average Marks: {average_marks:.2f}")
print(f"Students With Marks >= 80: {count_students}")
print("=" * 30)
# Out:
# ...
#        STUDENT RECORDS
# ...
# Total Students: 4
#
# Name       | Marks
# -------------------------
# Ali        | 85
# Sami       | 95
# Hamza      | 72
# Ayesha     | 90
#
# ...
# Highest Marks: 95
# Highest Student: Sami
# Average Marks: 85.50
# Students With Marks >= 80: 3
# ...
